# %%
import numpy as np
def remove_adjacent(nums):
  # +++your code here+++
  nums1=[]
  for i in range(0, len(nums)+1): 
        try:
          if nums[i] != nums[i+1]:
            nums1.append(nums[i])
        except:
           pass 
  array=np.array(nums[-1:])
  scalar=array
  if nums1[-1:] != nums[-1:]:
    nums1.append(scalar)
  return nums1

# %%
# Simple provided test() function used in main() to print
# what each function returns vs. what it's supposed to return.
def test(got, expected):
  if got == expected:
    prefix = ' OK '
  else:
    prefix = '  X '
  print('%s got: %s expected: %s' % (prefix, repr(got), repr(expected)))


# Calls the above functions with interesting inputs.
def main():
  print('remove_adjacent')
  test(remove_adjacent([1, 2, 2, 3]), [1, 2, 3])
  test(remove_adjacent([2, 2, 3, 3]), [2, 3])
  test(remove_adjacent([]), [])
  
if __name__ == '__main__':
  main()
# Out:
# remove_adjacent
#   X  got: [1, 2, 2] expected: [1, 2, 3]
#   X  got: [2, 2] expected: [2, 3]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-074f08b6cd97> in <cell line: 20>()
#      19
#      20 if __name__ == '__main__':
# ---> 21   main()
#
# <ipython-input-10-074f08b6cd97> in main()
#      14   test(remove_adjacent([1, 2, 2, 3]), [1, 2, 3])
#      15   test(remove_adjacent([2, 2,3,3]), [2, 3])
# ---> 16   test(remove_adjacent([]), [])
#      17
#      18
#
# <ipython-input-6-de08afe1c238> in remove_adjacent(nums)
#      11         except:
#      12            pass
# ---> 13   l_num=np.array(nums[-1:]).astype(int).item()
#      14   l_num1=np.array(nums1[-1:]).astype(int).item()
#      15   if (l_num) != (l_num1):
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
import numpy as np
nums=[1,3,5,6]
array=np.array(nums[-1:])  # Creating a NumPy array with a single element
scalar = array[0]          # Accessing the first (and only) element of the array

print(scalar)
n1=[]
n1.append(scalar)
print(n1)
# Out:
# 6
# [6]

# %%
 # Output: 42
# Out:
# 42
